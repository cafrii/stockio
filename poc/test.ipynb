# %%
stock_code = 5930
stk_cd = f'{stock_code:06}'
stk_cd
# Out:
# '005930'

# %%
print(f'None is printed as {None}')
# Out:
# None is printed as None

# %%
dt = { f'k{x}':x for x in range(5) }
print(dt)
del dt['k2']
dt.pop('k3')
print(dt)
# del dt['k100']
# dt.pop('k100')
dt.get()
print(dt)
# Out:
# {'k0': 0, 'k1': 1, 'k2': 2, 'k3': 3, 'k4': 4}
# {'k0': 0, 'k1': 1, 'k4': 4}
# {'k0': 0, 'k1': 1, 'k4': 4}
